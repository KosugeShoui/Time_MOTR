# %% [markdown]
# ## Attention Weight & Feature Map Visualization

# %%
import cv2
import os
from IPython.display import Video, display
from natsort import natsorted
import matplotlib.pyplot as plt

def create_video_from_frames(frame_folder, output_path, vis_name , fps=5):

    # Get a list of frame filenames sorted by name that include vis_name
    frames = natsorted([os.path.join(frame_folder, frame) for frame in os.listdir(frame_folder) if frame.endswith(('.png', '.jpg', '.jpeg')) and vis_name in frame])
    print(frames)
    if not frames:
        raise ValueError("No frames found with the specified vis_name in the filenames.")

    # Read the first frame to get the dimensions
    frame = cv2.imread(frames[0],)
    height, width, layers = frame.shape
    #frame = 1 - frame
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    #print(type(frame))
    #plt.imshow(frame)
    #plt.show()

    # Define the codec and create a VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    video = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    #for frame in frames:
        #img = cv2.imread(frame)
        #video.write(img)

    # Release the video writer object
    #video.release()

# %%
# Example usage
frame_folder = 'w_eval_attention'
save_dir = 'w_output_video'
name_list = ['src_time','src_notime','time_weight']
vis_name = name_list[1]
#
os.makedirs(save_dir,exist_ok=True)
output_path = os.path.join(save_dir,'test.mp4')
create_video_from_frames(frame_folder, output_path, vis_name, fps=5)
# Out:
# ['w_eval_attention/src_notime0.png', 'w_eval_attention/src_notime1.png', 'w_eval_attention/src_notime2.png', 'w_eval_attention/src_notime3.png', 'w_eval_attention/src_notime4.png', 'w_eval_attention/src_notime5.png', 'w_eval_attention/src_notime6.png', 'w_eval_attention/src_notime7.png', 'w_eval_attention/src_notime8.png', 'w_eval_attention/src_notime9.png', 'w_eval_attention/src_notime10.png', 'w_eval_attention/src_notime11.png', 'w_eval_attention/src_notime12.png', 'w_eval_attention/src_notime13.png', 'w_eval_attention/src_notime14.png', 'w_eval_attention/src_notime15.png', 'w_eval_attention/src_notime16.png', 'w_eval_attention/src_notime17.png', 'w_eval_attention/src_notime18.png', 'w_eval_attention/src_notime19.png', 'w_eval_attention/src_notime20.png', 'w_eval_attention/src_notime21.png', 'w_eval_attention/src_notime22.png', 'w_eval_attention/src_notime23.png', 'w_eval_attention/src_notime24.png', 'w_eval_attention/src_notime25.png', 'w_eval_attention/src_notime26.png', 'w_eval_attention/src_notime27.png', 'w_eval_attention/src_notime28.png', 'w_eval_attention/src_notime29.png', 'w_eval_attention/src_notime30.png', 'w_eval_attention/src_notime31.png', 'w_eval_attention/src_notime32.png', 'w_eval_attention/src_notime33.png', 'w_eval_attention/src_notime34.png', 'w_eval_attention/src_notime35.png', 'w_eval_attention/src_notime36.png', 'w_eval_attention/src_notime37.png', 'w_eval_attention/src_notime38.png', 'w_eval_attention/src_notime39.png', 'w_eval_attention/src_notime40.png', 'w_eval_attention/src_notime41.png', 'w_eval_attention/src_notime42.png', 'w_eval_attention/src_notime43.png', 'w_eval_attention/src_notime44.png', 'w_eval_attention/src_notime45.png', 'w_eval_attention/src_notime46.png', 'w_eval_attention/src_notime47.png', 'w_eval_attention/src_notime48.png', 'w_eval_attention/src_notime49.png', 'w_eval_attention/src_notime50.png', 'w_eval_attention/src_notime51.png', 'w_eval_attention/src_notime52.png', 'w_eval_attention/src_notime53.png', 'w_eval_attention/src_notime54.png', 'w_eval_attention/src_notime55.png', 'w_eval_attention/src_notime56.png', 'w_eval_attention/src_notime57.png', 'w_eval_attention/src_notime58.png', 'w_eval_attention/src_notime59.png', 'w_eval_attention/src_notime60.png', 'w_eval_attention/src_notime61.png', 'w_eval_attention/src_notime62.png', 'w_eval_attention/src_notime63.png', 'w_eval_attention/src_notime64.png', 'w_eval_attention/src_notime65.png', 'w_eval_attention/src_notime66.png', 'w_eval_attention/src_notime67.png', 'w_eval_attention/src_notime68.png', 'w_eval_attention/src_notime69.png', 'w_eval_attention/src_notime70.png', 'w_eval_attention/src_notime71.png', 'w_eval_attention/src_notime72.png', 'w_eval_attention/src_notime73.png', 'w_eval_attention/src_notime74.png', 'w_eval_attention/src_notime75.png', 'w_eval_attention/src_notime76.png', 'w_eval_attention/src_notime77.png', 'w_eval_attention/src_notime78.png', 'w_eval_attention/src_notime79.png', 'w_eval_attention/src_notime80.png', 'w_eval_attention/src_notime81.png', 'w_eval_attention/src_notime82.png', 'w_eval_attention/src_notime83.png', 'w_eval_attention/src_notime84.png', 'w_eval_attention/src_notime85.png', 'w_eval_attention/src_notime86.png', 'w_eval_attention/src_notime87.png', 'w_eval_attention/src_notime88.png', 'w_eval_attention/src_notime89.png', 'w_eval_attention/src_notime90.png', 'w_eval_attention/src_notime91.png', 'w_eval_attention/src_notime92.png', 'w_eval_attention/src_notime93.png', 'w_eval_attention/src_notime94.png', 'w_eval_attention/src_notime95.png', 'w_eval_attention/src_notime96.png', 'w_eval_attention/src_notime97.png', 'w_eval_attention/src_notime98.png', 'w_eval_attention/src_notime99.png']
